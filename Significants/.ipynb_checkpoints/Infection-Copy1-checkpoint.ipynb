# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from scipy.stats import  spearmanr

# %%
cyto=pd.read_excel("../Data_preprocessing/Scaled_data_12m.xlsx")

# %%
cytokines=[ 'lrti_1y', 'urti_1y', 'rti_1y', 'fever_1y',
       'gi_1y', 'any_1y']

# %%
useless=['verificeret_12y', 'verificeret_18y', 'lrti_3yr',
       'urti_3yr', 'rti_3yr', 'fever_3yr', 'gi_3yr', 'any_3yr',
       'genetic_risk_score_asthma','asthma_0_7yrs','crp_6mo', 'il_1β_6mo',
       'il_8_6mo', 'il_6_6mo', 'tnf_α_6mo','scale_bc',
       'scale_pm']

# %%
cyto.columns
# Out:
# Index(['Unnamed: 0', 'constrution_year', 'Area', 'floor_level', 'powerplant',
#        'road', 'motorway', 'forest', 'coastline', 'airport', 'farmland',
#        'industrial', 'carpet', 'cookerhood', 'passive', 'gastove', 'fireplace',
#        'scale_bc', 'scale_pm', 'scaled_bc', 'scaled_PM25', 'scaled_nox',
#        'scaled_no2', 'scaled_formaldehyd', 'scaled_acetone', 'scaled_acetald',
#        'no2_street', 'nox_street', 'pm25_street', 'asthma_0_7yrs', 'bmi_6_yrs',
#        'gestational_age', 'mother's_education_1yr', 'crp_6mo', 'il_1β_6mo',
#        'il_8_6mo', 'il_6_6mo', 'tnf_α_6mo', 'verificeret_12y',
#        'verificeret_18y', 'lrti_1y', 'urti_1y', 'rti_1y', 'fever_1y', 'gi_1y',
#        'any_1y', 'lrti_3yr', 'urti_3yr', 'rti_3yr', 'fever_3yr', 'gi_3yr',
#        'any_3yr', 'genetic_risk_score_asthma'],
#       dtype='str')

# %%
corr_mat=cyto.corr(method="spearman").drop(cytokines+useless,axis=0).loc[:,cytokines]

# %%
def calculate_pvalues(df):
    df = df._get_numeric_data()
    dfcols = pd.DataFrame(columns=df.columns)
    pvalues = dfcols.transpose()
    pvalues.index=df.columns
    corr = dfcols.transpose()
    corr.index=df.columns
    for r in df.columns:
        for c in df.columns:
            if c == r:
                pvalues.loc[r,c]=1
            else:
                df_corr = df.loc[:,[r,c]].dropna()
                pvalues.loc[r,c] = spearmanr(df_corr.loc[:,r], df_corr.loc[:,c])[1]
                corr.loc[r,c] = spearmanr(df_corr.loc[:,r], df_corr.loc[:,c])[0]
    return df.corr(method="spearman"),pvalues

# %%
corr,p=calculate_pvalues(cyto)

# %%
mask=p<0.05

# %%
p_shape=p.drop(cytokines+useless,axis=0).loc[:,cytokines]

# %%
soft_max=mask.drop(cytokines+useless,axis=0).loc[:,cytokines]

# %%
corr_shape=corr.drop(cytokines+useless,axis=0).loc[:,cytokines]

# %%
index1=["Indoor $PM_{2.5}$","Indoor Formalhyde","Street $NO_2$","Street $PM_{2,5}$","Street $NO_x$" ,"Indoor $NO_x$","Indoor Acetald"," Indoor Actone","Indoor Black Carbon","Urban $NO_x$","Urban $NO_x$","Urban $PM_{2,5}$","Indoor Humidity","Fel d1","Der f1"]

# %%
index2=["Der p1","Can f1","Indoor temperature","Cotinine hair","Genetics","Gestational age",'Constrution year','Area',
       'Floor level',"Airport" ,"Forest","Moterway","Road","Farmland"]

# %%
columns=["LRTI","URTI"," RI","Fever","GI","Any"]
index1=['Constrution year',"Area","Floor level","Powerplant","Road", "Moterway","Forest",'Coastline', 'Airport', 'Farmland', 'Industrial',
       'Carpet', 'Cookerhood', 'Passive', 'Gastove', 'Fireplace', 'Black Carbon',
       'PM$_{2.5}$', 'NO$_x$', 'NO$_2$', 'Formaldehyde',
       'Acetone', 'Acetaldehyde', 'Street level NO$_2$','Street level NO$_x$',
       'Street level PM$_{2.5}$', 'BMI 6 years', 'Gestational age',
       'Education of Mother first year' ]

# %%
corr_shape
# Out:
#                          lrti_1y   urti_1y    rti_1y  fever_1y     gi_1y  \
# Unnamed: 0              0.061616 -0.035280 -0.020043  0.049403 -0.089254
# constrution_year        0.043632 -0.011588  0.007258 -0.104675 -0.079963
# Area                   -0.025075  0.126245  0.116186  0.113626  0.027352
# floor_level            -0.023772  0.004426 -0.018315  0.007973 -0.003718
# powerplant             -0.041456 -0.058171 -0.064658 -0.019326  0.045739
# road                   -0.078851  0.015664 -0.003386  0.087330  0.079328
# motorway                0.020844 -0.055884 -0.037002 -0.064957  0.087856
# forest                  0.096553  0.051126  0.078227 -0.057193 -0.099882
# coastline              -0.090766 -0.051636 -0.074335  0.028657 -0.000031
# airport                 0.007326  0.075333  0.049362  0.067127  0.001021
# farmland                0.049019  0.025160  0.031728 -0.005056 -0.050237
# industrial              0.025808 -0.039033 -0.012824 -0.097000  0.027444
# carpet                 -0.029173  0.023030  0.008645 -0.026741  0.041336
# cookerhood              0.047991  0.010603  0.009306 -0.033096 -0.045115
# passive                -0.057798 -0.021726 -0.032024 -0.060848 -0.009755
# gastove                -0.026253 -0.049705 -0.053938  0.084233  0.060507
# fireplace               0.003105 -0.028454 -0.032750  0.062897 -0.008666
# scaled_bc              -0.029514 -0.084301 -0.088992 -0.062050 -0.007608
# scaled_PM25             0.005641 -0.080054 -0.070590 -0.077438 -0.001268
# scaled_nox             -0.028160 -0.076107 -0.083462  0.028252  0.015853
# scaled_no2             -0.011153 -0.003989 -0.002820  0.089684  0.003566
# scaled_formaldehyd     -0.069968 -0.040731 -0.048866 -0.083611 -0.041628
# scaled_acetone         -0.080521  0.035315  0.002297  0.004295  0.092580
# scaled_acetald         -0.091294  0.028723 -0.010458  0.048714  0.027861
# no2_street             -0.081271 -0.038138 -0.063521 -0.008776 -0.014964
# nox_street             -0.071375 -0.044047 -0.069906 -0.004797 -0.015980
# pm25_street            -0.077366 -0.052858 -0.086026  0.004057 -0.004194
# bmi_6_yrs               0.145127  0.044875  0.076982  0.140627 -0.031003
# gestational_age         0.028436  0.070389  0.078858  0.070201  0.032679
# mother's_education_1yr -0.101552  0.031840 -0.001410  0.086173  0.038320
#
#                           any_1y
# Unnamed: 0             -0.017937
# constrution_year       -0.056217
# Area                    0.146000
# floor_level            -0.006641
# powerplant             -0.023381
# road                    0.045522
# motorway               -0.029480
# forest                  0.010359
# coastline              -0.039800
# airport                 0.071625
# farmland               -0.006146
# industrial             -0.049409
# carpet                 -0.003722
# cookerhood             -0.024946
# passive                -0.032215
# gastove                 0.000438
# fireplace               0.016329
# scaled_bc              -0.083948
# scaled_PM25            -0.076550
# scaled_nox             -0.061910
# scaled_no2              0.033052
# scaled_formaldehyd     -0.061268
# scaled_acetone          0.030232
# scaled_acetald          0.026607
# no2_street             -0.056015
# nox_street             -0.061173
# pm25_street            -0.052751
# bmi_6_yrs               0.108757
# gestational_age         0.102956
# mother's_education_1yr  0.051756

# %%
dict(zip(corr_shape.columns,columns))
# Out:
# {'LRTI': 'LRTI',
#  'URTI': 'URTI',
#  ' RI': ' RI',
#  'Fever': 'Fever',
#  'GI': 'GI',
#  'Any': 'Any'}

# %%
dict(zip(corr_shape.index,index1))
# Out:
# {'Constrution year': 'Constrution year',
#  'Area': 'Area',
#  'Floor level': 'Floor level',
#  'Powerplant': 'Powerplant',
#  'Road': 'Road',
#  'Moterway': 'Moterway',
#  'Forest': 'Forest',
#  'Coastline': 'Coastline',
#  'Airport': 'Airport',
#  'Farmland': 'Farmland',
#  'Industrial': 'Industrial',
#  'Carpet': 'Carpet',
#  'Cookerhood': 'Cookerhood',
#  'Passive': 'Passive',
#  'Gastove': 'Gastove',
#  'Fireplace': 'Fireplace',
#  'Black Carbon': 'Black Carbon',
#  'PM$_{2.5}$': 'PM$_{2.5}$',
#  'NO$_x$': 'NO$_x$',
#  'NO$_2$': 'NO$_2$',
#  'Formaldehyde': 'Formaldehyde',
#  'Acetone': 'Acetone',
#  'Acetaldehyde': 'Acetaldehyde',
#  'Street level NO$_2$': 'Street level NO$_2$',
#  'Street level NO$_x$': 'Street level NO$_x$',
#  'Street level PM$_{2.5}$': 'Street level PM$_{2.5}$',
#  'BMI 6 years': 'BMI 6 years',
#  'Gestational age': 'Gestational age',
#  'Education of Mother first year': 'Education of Mother first year'}

# %%
corr_shape=corr_shape.rename(dict(zip(corr_shape.columns,columns)),axis=1)
corr_shape=corr_shape.rename(dict(zip(corr_shape.index,index1)),axis=0)

# %%
corr_shape
# Out:
#                                     LRTI      URTI        RI     Fever  \
# Constrution year                0.061616 -0.035280 -0.020043  0.049403
# Area                            0.043632 -0.011588  0.007258 -0.104675
# Floor level                    -0.025075  0.126245  0.116186  0.113626
# Powerplant                     -0.023772  0.004426 -0.018315  0.007973
# Road                           -0.041456 -0.058171 -0.064658 -0.019326
# Moterway                       -0.078851  0.015664 -0.003386  0.087330
# Forest                          0.020844 -0.055884 -0.037002 -0.064957
# Coastline                       0.096553  0.051126  0.078227 -0.057193
# Airport                        -0.090766 -0.051636 -0.074335  0.028657
# Farmland                        0.007326  0.075333  0.049362  0.067127
# Industrial                      0.049019  0.025160  0.031728 -0.005056
# Carpet                          0.025808 -0.039033 -0.012824 -0.097000
# Cookerhood                     -0.029173  0.023030  0.008645 -0.026741
# Passive                         0.047991  0.010603  0.009306 -0.033096
# Gastove                        -0.057798 -0.021726 -0.032024 -0.060848
# Fireplace                      -0.026253 -0.049705 -0.053938  0.084233
# Black Carbon                    0.003105 -0.028454 -0.032750  0.062897
# PM$_{2.5}$                     -0.029514 -0.084301 -0.088992 -0.062050
# NO$_x$                          0.005641 -0.080054 -0.070590 -0.077438
# NO$_2$                         -0.028160 -0.076107 -0.083462  0.028252
# Formaldehyde                   -0.011153 -0.003989 -0.002820  0.089684
# Acetone                        -0.069968 -0.040731 -0.048866 -0.083611
# Acetaldehyde                   -0.080521  0.035315  0.002297  0.004295
# Street level NO$_2$            -0.091294  0.028723 -0.010458  0.048714
# Street level NO$_x$            -0.081271 -0.038138 -0.063521 -0.008776
# Street level PM$_{2.5}$        -0.071375 -0.044047 -0.069906 -0.004797
# BMI 6 years                    -0.077366 -0.052858 -0.086026  0.004057
# Gestational age                 0.145127  0.044875  0.076982  0.140627
# Education of Mother first year  0.028436  0.070389  0.078858  0.070201
# mother's_education_1yr         -0.101552  0.031840 -0.001410  0.086173
#
#                                       GI       Any
# Constrution year               -0.089254 -0.017937
# Area                           -0.079963 -0.056217
# Floor level                     0.027352  0.146000
# Powerplant                     -0.003718 -0.006641
# Road                            0.045739 -0.023381
# Moterway                        0.079328  0.045522
# Forest                          0.087856 -0.029480
# Coastline                      -0.099882  0.010359
# Airport                        -0.000031 -0.039800
# Farmland                        0.001021  0.071625
# Industrial                     -0.050237 -0.006146
# Carpet                          0.027444 -0.049409
# Cookerhood                      0.041336 -0.003722
# Passive                        -0.045115 -0.024946
# Gastove                        -0.009755 -0.032215
# Fireplace                       0.060507  0.000438
# Black Carbon                   -0.008666  0.016329
# PM$_{2.5}$                     -0.007608 -0.083948
# NO$_x$                         -0.001268 -0.076550
# NO$_2$                          0.015853 -0.061910
# Formaldehyde                    0.003566  0.033052
# Acetone                        -0.041628 -0.061268
# Acetaldehyde                    0.092580  0.030232
# Street level NO$_2$             0.027861  0.026607
# Street level NO$_x$            -0.014964 -0.056015
# Street level PM$_{2.5}$        -0.015980 -0.061173
# BMI 6 years                    -0.004194 -0.052751
# Gestational age                -0.031003  0.108757
# Education of Mother first year  0.032679  0.102956
# mother's_education_1yr          0.038320  0.051756

# %%
fig,ax=plt.subplots(1,1,figsize=(7.5,15))
g=sns.heatmap(corr_shape, fmt='g',ax=ax,vmin=-0.5,vmax=0.5,cmap = 'seismic')
for i in range(corr_shape.shape[0]):
    for j in range(corr_shape.shape[1]):
        if p_shape.iloc[i, j]<0.05:
            corr = '{:.2f}'.format(corr_shape.iloc[i, j].round(2)),
            pval = p_shape.iloc[i, j].round(1)
            if p_shape.iloc[i, j]*p_shape.shape[0]<0.05:
                ax.text(j+0.5, i+0.3, corr[0], ha='center', va='center', fontsize=12, color='white', fontweight='bold')
                ax.text(j+0.5, i+0.7, "**", ha='center', va='center', fontsize=12, color='white', fontweight='bold')
            else:
                ax.text(j+0.5, i+0.3, corr[0], ha='center', va='center', fontsize=12, color='white', fontweight='bold')
                ax.text(j+0.5, i+0.7, "*", ha='center', va='center', fontsize=12, color='white', fontweight='bold')
ax.set_xticklabels(ax.get_xticklabels(), fontsize=14, fontweight='bold')
ax.set_yticklabels(ax.get_yticklabels(), fontsize=14, fontweight='bold')         
fig.savefig("../Plots/infections_responds_exposures.png",bbox_inches="tight")
